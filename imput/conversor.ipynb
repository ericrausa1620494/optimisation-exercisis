# %%
from sisl import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sisl import *
#
# ModuleNotFoundError: No module named 'sisl'

# %%
molecule=Geometry.read("moleculatasca4.xyz")

# %%
molecule.write("structure.fdf")

# %%
structure=Geometry.read("structure.fdf")
structure.plot()
